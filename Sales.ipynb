# %%
import pandas as pd

# %%
df=pd.read_csv('BlackFriday.csv')

# %%
df
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 537572  1004737  P00193542      M  36-45          16             C
# 537573  1004737  P00111142      M  36-45          16             C
# 537574  1004737  P00345942      M  36-45          16             C
# 537575  1004737  P00285842      M  36-45          16             C
# 537576  1004737  P00118242      M  36-45          16             C
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 537577 entries, 0 to 537576
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     537577 non-null  int64
#  1   Product_ID                  537577 non-null  object
#  2   Gender                      537577 non-null  object
#  3   Age                         537577 non-null  object
#  4   Occupation                  537577 non-null  int64
#  5   City_Category               537577 non-null  object
#  6   Stay_In_Current_City_Years  537577 non-null  object
#  7   Marital_Status              537577 non-null  int64
#  8   Product_Category_1          537577 non-null  int64
#  9   Product_Category_2          370591 non-null  float64
#  10  Product_Category_3          164278 non-null  float64
#  11  Purchase                    537577 non-null  int64
# dtypes: float64(2), int64(5), object(5)
# ...

# %%
df=df.drop('Product_Category_2',axis=1)

# %%
df.isnull().sum()
# Out:
# User_ID                       0
# Product_ID                    0
# Gender                        0
# Age                           0
# Occupation                    0
# City_Category                 0
# Stay_In_Current_City_Years    0
# Marital_Status                0
# Product_Category_1            0
# Purchase                      0
# dtype: int64

# %%
df['User_ID'].unique()
# Out:
# array([1000001, 1000002, 1000003, ..., 1004113, 1005391, 1001529],
#       shape=(5891,))

# %%
df['Product_ID'].unique()
# Out:
# array(['P00069042', 'P00248942', 'P00087842', ..., 'P00038842',
#        'P00295642', 'P00091742'], shape=(3623,), dtype=object)

# %%
df['Gender'].unique()
# Out:
# array(['F', 'M'], dtype=object)

# %%
df['Age'].unique()
# Out:
# array(['0-17', '55+', '26-35', '46-50', '51-55', '36-45', '18-25'],
#       dtype=object)

# %%
df['Occupation'].unique()
# Out:
# array([10, 16, 15,  7, 20,  9,  1, 12, 17,  0,  3,  4, 11,  8, 19,  2, 18,
#         5, 14, 13,  6])

# %%
df['City_Category'].unique()
# Out:
# array(['A', 'C', 'B'], dtype=object)

# %%
df['Stay_In_Current_City_Years'].unique()
# Out:
# array(['2', '4+', '3', '1', '0'], dtype=object)

# %%
df['Marital_Status'].unique()
# Out:
# array([0, 1])

# %%
df['Marital_Status']=df['Marital_Status'].astype("str")

# %%
df['Marital_Status']=df['Marital_Status'].str.replace('0','Unmarried').str.replace('1','Married')

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years Marital_Status  Product_Category_1  Purchase
# 0                          2      Unmarried                   3      8370
# 1                          2      Unmarried                   1     15200
# 2                          2      Unmarried                  12      1422
# 3                          2      Unmarried                  12      1057
# 4                         4+      Unmarried                   8      7969

# %%
df['Gender']=df['Gender'].astype("str")

# %%
df['City_Category']=df['City_Category'].astype("str")

# %%
df['City_Category']=df['City_Category'].str.replace('A','Kolkata').str.replace('B','Delhi').str.replace('C','Mumbai')

# %%
#Use for loop Method

# %%
for i in df.columns:
  print(i,':',df[i].unique())
# Out:
# User_ID : [1000001 1000002 1000003 ... 1004113 1005391 1001529]
# Product_ID : ['P00069042' 'P00248942' 'P00087842' ... 'P00038842' 'P00295642'
#  'P00091742']
# Gender : ['F' 'M']
# Age : ['0-17' '55+' '26-35' '46-50' '51-55' '36-45' '18-25']
# Occupation : [10 16 15  7 20  9  1 12 17  0  3  4 11  8 19  2 18  5 14 13  6]
# City_Category : ['Kolkata' 'Mumbai' 'Delhi']
# Stay_In_Current_City_Years : ['2' '4+' '3' '1' '0']
# Marital_Status : ['Unmarried' 'Married']
# Product_Category_1 : [ 3  1 12  8  5  4  2  6 14 11 13 15  7 16 18 10 17  9]
# Purchase : [ 8370 15200  1422 ... 14539 11120 18426]

# %%
for i in df.columns:
  print(i,':',df[i].describe())
  print("-"*40)
# Out:
# User_ID : count    5.375770e+05
# mean     1.002992e+06
# std      1.714393e+03
# min      1.000001e+06
# 25%      1.001495e+06
# 50%      1.003031e+06
# 75%      1.004417e+06
# max      1.006040e+06
# Name: User_ID, dtype: float64
# ----------------------------------------
# Product_ID : count        537577
# unique         3623
# top       P00265242
# freq           1858
# Name: Product_ID, dtype: object
# ----------------------------------------
# Gender : count     537577
# unique         2
# top            M
# freq      405380
# Name: Gender, dtype: object
# ----------------------------------------
# Age : count     537577
# unique         7
# top        26-35
# freq      214690
# Name: Age, dtype: object
# ----------------------------------------
# Occupation : count    537577.00000
# mean          8.08271
# std           6.52412
# min           0.00000
# 25%           2.00000
# 50%           7.00000
# 75%          14.00000
# max          20.00000
# ...

# %%
df['Gender'].value_counts()
# Out:
# Gender
# M    405380
# F    132197
# Name: count, dtype: int64

# %%
# Use Pie Chart

# %%
df.groupby('Gender').size().plot(kind="pie",autopct="%.2f",title="Gender Ratio")
# Out:
# <Axes: title={'center': 'Gender Ratio'}>

# %%
df.groupby('Gender').sum()['Purchase']
# Out:
# Gender
# F    1164624021
# M    3853044357
# Name: Purchase, dtype: int64

# %%
df.groupby('Gender').sum()['Purchase'].plot(kind="pie",autopct="%.2f")
# Out:
# <Axes: ylabel='Purchase'>

# %%
df.groupby('Gender').mean(numeric_only=True)['Purchase'].plot(kind="pie",autopct="%.2f")
# Out:
# <Axes: ylabel='Purchase'>

# %%
df.groupby('Gender').mean(numeric_only=True)['Purchase']
# Out:
# Gender
# F    8809.761349
# M    9504.771713
# Name: Purchase, dtype: float64

# %%
#Use Bar Chart

# %%
df.groupby('Age').size()
# Out:
# Age
# 0-17      14707
# 18-25     97634
# 26-35    214690
# 36-45    107499
# 46-50     44526
# 51-55     37618
# 55+       20903
# dtype: int64

# %%
df["Age"].unique()

# %%
df.groupby('Age').size().plot(kind="bar",title="Age Ratio")
# Out:
# <Axes: title={'center': 'Age Ratio'}, xlabel='Age'>

# %%
df.groupby('Age')['Product_ID'].nunique()
# Out:
# Age
# 0-17     2300
# 18-25    3213
# 26-35    3419
# 36-45    3318
# 46-50    3099
# 51-55    2877
# 55+      2573
# Name: Product_ID, dtype: int64

# %%
df.Age.unique()
# Out:
# array(['0-17', '55+', '26-35', '46-50', '51-55', '36-45', '18-25'],
#       dtype=object)

# %%
lst=[]
for i in df["Age"].unique():
  print(i,':',df[df["Age"]==i]['Product_ID'].nunique())
# Out:
# 0-17 : 2300
# 55+ : 2573
# 26-35 : 3419
# 46-50 : 3099
# 51-55 : 2877
# 36-45 : 3318
# 18-25 : 3213

# %%
df.groupby('Age')['Product_ID'].nunique().plot(kind="bar")
# Out:
# <Axes: xlabel='Age'>

# %%
df.groupby("Age").sum()["Purchase"]
# Out:
# Age
# 0-17      132659006
# 18-25     901669280
# 26-35    1999749106
# 36-45    1010649565
# 46-50     413418223
# 51-55     361908356
# 55+       197614842
# Name: Purchase, dtype: int64

# %%
df.groupby("Age").sum()["Purchase"].plot(kind="bar")
# Out:
# <Axes: xlabel='Age'>

# %%
df.groupby("Age").mean(numeric_only=True)["Purchase"]
# Out:
# Age
# 0-17     9020.126878
# 18-25    9235.197575
# 26-35    9314.588970
# 36-45    9401.478758
# 46-50    9284.872277
# 51-55    9620.616620
# 55+      9453.898579
# Name: Purchase, dtype: float64

# %%
df.groupby("Age").mean(numeric_only=True)["Purchase"].plot(kind="bar").plot(kind="bar")
# Out:
# []

# %%
import seaborn as sns

# %%
sns.countplot(x="Age",data=df,hue="Gender")
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
sns.countplot(x="Gender",data=df,hue="Marital_Status")
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
df.groupby("City_Category").size().plot(kind="bar")
# Out:
# <Axes: xlabel='City_Category'>

# %%
df.groupby("City_Category").size().plot(kind="pie",autopct="%.2f")
# Out:
# <Axes: >

# %%
sns.countplot(x="City_Category",data=df,hue="Marital_Status")
# Out:
# <Axes: xlabel='City_Category', ylabel='count'>

# %%
df.groupby("City_Category").sum()["Purchase"]
# Out:
# City_Category
# A    1295668797
# B    2083431612
# C    1638567969
# Name: Purchase, dtype: int64

# %%
df.groupby("City_Category").mean(numeric_only=True)["Purchase"]
# Out:
# City_Category
# A    8958.011014
# B    9198.657848
# C    9844.441855
# Name: Purchase, dtype: float64

# %%
df.groupby("City_Category").sum()["Purchase"].plot(kind='pie',autopct="%.2f")
# Out:
# <Axes: ylabel='Purchase'>

# %%
df.groupby("City_Category").mean(numeric_only=True)["Purchase"].plot(kind='pie',autopct="%.2f")
# Out:
# <Axes: ylabel='Purchase'>
